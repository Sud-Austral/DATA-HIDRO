# %%
from os import scandir, getcwd
import pandas as pd
import time
import numpy as np
import glob
import unidecode

def ls(ruta = getcwd()):
    return [arch.name for arch in scandir(ruta) if arch.is_file()]

# %%
SOLICITUDES = []
for i in ls():
    if "SOLICITUDES" in i: #and "REGISTRO" not in i:
        SOLICITUDES.append(i)
    if "solicitudes" in i: #and "registro" not in i:
        SOLICITUDES.append(i)
        
SOLICITUDES
# Out:
# ['SOLICITUDES-NC-INGRESADAS-ABRIL-2016.xls',
#  'SOLICITUDES-NC-INGRESADAS-AGOSTO-2016.xls',
#  'SOLICITUDES-NC-INGRESADAS-EN-NOVIEMBRE-DE-2016.xls',
#  'SOLICITUDES-NC-INGRESADAS-EN-SEPTIEMBRE-DE-2016.xls',
#  'SOLICITUDES-NC-INGRESADAS-OCTUBRE-DE-2014.xls',
#  'SOLICITUDES_CONCEDIDAS-o_APROBADAS_EN_EL_MES_DE_OCTUBRE_DE_2013.xls',
#  'SOLICITUDES_CONCEDIDAS_O_APROBADAS_EN_EL_MES_DE_ABRIL_DE_2013.xls',
#  'SOLICITUDES_CONCEDIDAS_O_APROBADAS_EN_EL_MES_DE_DICIEMBRE_2013.xls',
#  'SOLICITUDES_CONCEDIDAS_O_APROBADAS_EN_EL_MES_DE_MARZO_DE_2013.xls',
#  'SOLICITUDES_CONCEDIDAS_O_APROBADAS_EN_EL_MES_DE_NOVIEMBRE_2013.xls',
#  'SOLICITUDES_CONCEDIDAS_O_APROBADAS_MES_DE_AGOSTO_DE_2013.xls',
#  'SOLICITUDES_CONCEDIDAS_O_APROBADAS_MES_DE_MAYO_DE_2013.xls',
#  'SOLICITUDES_DE_APROVECHAMIENTO_NO_CONSUNTIVOS_INGRESADAS_EN_EL_MES_DE_MARZO_DE_2012.xls',
#  'SOLICITUDES_INGRESADAS_A_TRAMITE_ABRIL__2012.xls',
#  'SOLICITUDES_INGRESADAS_A_TRAMITE_AGOSTO_DE_2012.xls',
#  'SOLICITUDES_INGRESADAS_A_TRAMITE_DICIEMBRE_2011.xls',
#  'SOLICITUDES_INGRESADAS_A_TRAMITE_DICIEMBRE_DE_2012.xls',
#  'SOLICITUDES_INGRESADAS_A_TRAMITE_ENERO_2012.xls',
#  'SOLICITUDES_INGRESADAS_A_TRAMITE_ENERO_2013.xls',
#  'SOLICITUDES_INGRESADAS_A_TRAMITE_EN_ABRIL_DE_2013.xls',
#  'SOLICITUDES_INGRESADAS_A_TRAMITE_EN_AGOSTO_DE_2013.xls',
#  'SOLICITUDES_INGRESADAS_A_TRAMITE_EN_DICIEMBRE_2013.xls',
#  'SOLICITUDES_INGRESADAS_A_TRAMITE_EN_MAYO_DE_2013.xls',
#  'SOLICITUDES_INGRESADAS_A_TRAMITE_EN_NOVIEMBRE_2013.xls',
#  'SOLICITUDES_INGRESADAS_A_TRAMITE_EN_OCTUBRE_2013.xls',
#  'SOLICITUDES_INGRESADAS_A_TRAMITE_EN_SEPTIEMBRE-2013.xls',
#  'SOLICITUDES_INGRESADAS_A_TRAMITE_FEBRERO_2012.xls',
#  'SOLICITUDES_INGRESADAS_A_TRAMITE_FEBRERO_DE_2013.xls',
#  'SOLICITUDES_INGRESADAS_A_TRAMITE_JULIO_2012.xls',
#  'SOLICITUDES_INGRESADAS_A_TRAMITE_JULIO_DE_2013.xls',
#  'SOLICITUDES_INGRESADAS_A_TRAMITE_JUNIO_2012.xls',
#  'SOLICITUDES_INGRESADAS_A_TRAMITE_JUNIO_DE_2013.xls',
#  'SOLICITUDES_INGRESADAS_A_TRAMITE_MARZO_DE_2013.xls',
#  'SOLICITUDES_INGRESADAS_A_TRAMITE_MAYO_2012.XLSX.xls',
#  'SOLICITUDES_INGRESADAS_A_TRAMITE_NOVIEMBRE_DE_2012.xls',
#  'SOLICITUDES_INGRESADAS_A_TRAMITE_OCTUBRE_DE_2012.xls',
#  'SOLICITUDES_INGRESADAS_A_TRAMITE_SEPTIEMBRE_DE_2012.xls',
#  'SOLICITUDES_INGRESADAS_EN_ABRIL_DE_2019.xls',
#  'SOLICITUDES_INGRESADAS_EN_AGOSTO_DE_2017.xls',
#  'SOLICITUDES_INGRESADAS_EN_DICIEMBRE_DE_2018.xlsx',
#  'SOLICITUDES_INGRESADAS_EN_ENERO_DE_2017.xls',
#  'SOLICITUDES_INGRESADAS_EN_JULIO_DE_2018.xls',
#  'SOLICITUDES_INGRESADAS_EN_NOVIEMBRE_DE_2018.xls',
#  'SOLICITUDES_INGRESADAS_EN_OCTUBRE_DE_2017.xls',
#  'SOLICITUDES_INGRESADAS_EN_OCTUBRE_DE_2018.xls',
#  'SOLICITUDES_INGRESADAS_EN_SEPTIEMBRE_DE_2017.xls',
#  'SOLICITUDES_INGRESADAS_JULIO_2015.xls',
#  'SOLICITUDES_NC_abril2015.xls',
#  'SOLICITUDES_NC_INGRESADAS_AGOSTO_2015.xls',
#  'SOLICITUDES_NC_INGRESADAS_AGOSTO_DE_2014.xls',
#  'SOLICITUDES_NC_INGRESADAS_DICIEMBRE_2015.xls',
#  'SOLICITUDES_NC_INGRESADAS_ENERO_2016.xls',
#  'SOLICITUDES_NC_INGRESADAS_ENERO_DEL_2015.xls',
#  'SOLICITUDES_NC_INGRESADAS_EN_ABRIL_DE_2017.xls',
#  'SOLICITUDES_NC_INGRESADAS_EN_ABRIL_DE_2018.xls',
#  'SOLICITUDES_NC_INGRESADAS_EN_AGOSTO_DE_2018.xls',
#  'SOLICITUDES_NC_INGRESADAS_EN_AGOSTO_DE_2019.xls',
#  'SOLICITUDES_NC_INGRESADAS_EN_DICIEMBRE_DE_2017.xls',
#  'SOLICITUDES_NC_INGRESADAS_EN_DICIEMBRE_DE_2019.xls',
#  'SOLICITUDES_NC_INGRESADAS_EN_ENERO_DE_2018.xls',
#  'SOLICITUDES_NC_INGRESADAS_EN_ENERO_DE_2019.xls',
#  'SOLICITUDES_NC_INGRESADAS_EN_ENERO_DE_2020.xls',
#  'SOLICITUDES_NC_INGRESADAS_EN_FEBRERO_DE_2018.xls',
#  'SOLICITUDES_NC_INGRESADAS_EN_FEBRERO_DE_2019.xls',
#  'SOLICITUDES_NC_INGRESADAS_EN_FEBRERO_DE_2020.xls',
#  'SOLICITUDES_NC_INGRESADAS_EN_JULIO_2017.xls',
#  'SOLICITUDES_NC_INGRESADAS_EN_JULIO_DE_2016.xls',
#  'SOLICITUDES_NC_INGRESADAS_EN_JULIO_DE_2019.xls',
#  'SOLICITUDES_NC_INGRESADAS_EN_JULIO_DE_2020.xls',
#  'SOLICITUDES_NC_INGRESADAS_EN_JUNIO_2016.xls',
#  'SOLICITUDES_NC_INGRESADAS_EN_JUNIO_DE_2017.xls',
#  'SOLICITUDES_NC_INGRESADAS_EN_JUNIO_DE_2018.xls',
#  'SOLICITUDES_NC_INGRESADAS_EN_JUNIO_DE_2019.xls',
#  'SOLICITUDES_NC_INGRESADAS_EN_JUNIO_DE_2020.xls',
#  'SOLICITUDES_NC_INGRESADAS_EN_MARZO_2017.xls',
#  'SOLICITUDES_NC_INGRESADAS_EN_MARZO_DE_2018.xls',
#  'SOLICITUDES_NC_INGRESADAS_EN_MARZO_DE_2019.xls',
#  'SOLICITUDES_NC_INGRESADAS_EN_MARZO_DE_2020.xls',
#  'SOLICITUDES_NC_INGRESADAS_EN_MAYO_DE_2017.xls',
#  'SOLICITUDES_NC_INGRESADAS_EN_MAYO_DE_2018.xls',
#  'SOLICITUDES_NC_INGRESADAS_EN_MAYO_DE_2019.xls',
#  'SOLICITUDES_NC_INGRESADAS_EN_MAYO_DE_2020_(1).xls',
#  'SOLICITUDES_NC_INGRESADAS_EN_NOVIEMBRE_DE_2014.xls',
#  'SOLICITUDES_NC_INGRESADAS_EN_NOVIEMBRE_DE_2017.xls',
#  'SOLICITUDES_NC_INGRESADAS_EN_NOVIEMBRE_DE_2019.xls',
#  'SOLICITUDES_NC_INGRESADAS_EN_OCTUBRE_DE_2016.xls',
#  'SOLICITUDES_NC_INGRESADAS_EN_OCTUBRE_DE_2019.xls',
#  'SOLICITUDES_NC_INGRESADAS_EN_SEPTIEMBRE_DE_2018.xls',
#  'SOLICITUDES_NC_INGRESADAS_EN_SEPTIEMBRE_DE_2019.xls',
#  'SOLICITUDES_NC_INGRESADAS_EN_SEPTIEMBRE_DE_2020.xls',
#  'SOLICITUDES_NC_INGRESADAS_FEBRERO_2016.xls',
#  'SOLICITUDES_NC_INGRESADAS_FEBRERO_DEL_2015.xls',
#  'SOLICITUDES_NC_INGRESADAS_FEBRERO_DE_2017.xls',
#  'SOLICITUDES_NC_INGRESADAS_JULIO_DE_2014.xls',
#  'SOLICITUDES_NC_INGRESADAS_JUNIO_DEL_2015.xls',
#  'SOLICITUDES_NC_INGRESADAS_JUNIO_DE_2014.xls',
#  'SOLICITUDES_NC_INGRESADAS_MARZO_2016.xls',
#  'SOLICITUDES_NC_INGRESADAS_MAYO_2016.xls',
#  'SOLICITUDES_NC_INGRESADAS_MAYO_DE_2014.xls',
#  'SOLICITUDES_NC_INGRESADAS_MES_DE_DICIEMBRE_2016.xls',
#  'SOLICITUDES_NC_INGRESADAS_NOVIEMBRE_2015.xls',
#  'SOLICITUDES_NC_INGRESADAS_OCTUBRE_2015.xls',
#  'solicitudes_nc_ingresadas_sep2015.xls',
#  'SOLICITUDES_NC_INGRESADAS_SEPTIEMBRE_DE_2014.xls',
#  'SOLICITUDES__marzo2015.xls',
#  'SOLICITUDES__mayo_2015.xls']

# %%
salida = []
derechos_aux = []
for i in SOLICITUDES:
    index = 0
    #flag = True
    while True:
        columna1 = pd.read_excel(i, skiprows=index).columns[0]
        if columna1 == "N°" or columna1 == "Número" or columna1 == "Numero" or columna1 == "Numero ":
            derechos_aux.append(i)
            salida.append(pd.read_excel(i, skiprows=index).copy())
            break
        if(index > 10):
            print(i)
            break
        index += 1

# %%
for i in range(len(salida)):
    if(len(salida[i].columns) != 39):
        print(i)
        print(SOLICITUDES[i])

# %%
for i in range(len(salida)):
    print(i)
    print(SOLICITUDES[i])
    print(len(salida[i].columns))
    print("*********************************************")

# %%
columnas = []
for i in salida[0].columns:
    print(i.replace("\n",""))
    columnas.append(i.replace("\n",""))

# %%
for i in salida[4].columns:
    if i not in columnas:
        print(i)

# %%
for i in range(len(salida[0].columns)):
    try:
        print(salida[0].columns[i])
        print("-")
        print(salida[4].columns[i])
    except:
        pass
        #print(salida[0].columns[i])
    print("***************************************")

# %%
#DATOS DE SOLICITUDES DATA HIDRO
def verificarColumnas(data, referencia):
    ruta = "Referencia/"
    df = data
    df = df[df.columns.dropna()]
    df = df.loc[:,~df.columns.duplicated()]
    
    ref = pd.read_excel(ruta + referencia, skiprows=4)
    
    existe = False
    columna = 0    
    #Eliminar Columnas que sobran    
    for col in df.columns:        
        for colRef in ref.columns:
            
            colCom = col
            colRefCom = colRef
            
            if "\n" in colRef.lower():
                colRefCom = colRef.replace("\n","")
            if "\n" in col.lower():
                colCom = col.replace("\n","")
            if unidecode.unidecode(colCom.lower()) == unidecode.unidecode(colRefCom.lower()):
                #print("existe la columna" + col)
                existe = True
            if "número" in col.lower() or "numero" in col.lower():
                existe = True
            if "region" in col.lower() or "región" in col.lower():
                existe = True
            if "codigo de expediente" in col.lower() or "código de expediente" in col.lower():
                existe = True
                
        if existe == False:
            
            del df[col]
            #df.to_csv(csvPorVerificar, index = False)
            print("se Eliminó la columna " + col)
            
        existe = False   
    #Agregar columnas faltantes    
    for colRef in ref.columns:        
        for col in df.columns:
            if col.lower() == colRef.lower():
                #print("existe la columna" + col)
                existe = True
        if "\n" in colRef.lower():
            colRefCom = colRef.replace("\n","")
        if colRef == "Región":
            existe = True
        if colRef == "Region":
            existe = True
        if colRefCom.lower() == "código de expediente":
            existe = True
        if colRefCom.lower() == "codigo de expediente":
            existe = True
            
        if existe == False:
            
            df.insert(columna,colRef,'')
            #df.to_csv(csvPorVerificar, index = False)
            print("se agregó la columna " + colRef)
        columna+=1
        existe = False
    '''    
    if "Region" in str(df.iloc[0]):
       
        region = df["Region"]
        del df["Región"]
        df.insert(3, "Región", region)
        del df["Region"]'''
    
    df.rename(columns = {"Region":"Región", "Numero":"Número", "Codigo de Expediente":"Código de Expediente", "Codigo de \nExpediente":"Código de Expediente", "Código de \nExpediente":"Código de Expediente" }, inplace = True)
    #df.rename(columns = {"Numero":"Número"}, inplace = True)
    #print(df)
    
    if "Número" in str(df.iloc[0]):
        del df["N°"]
        df.insert(0, "N°", df["Número"])
        del df["Número"]
    #print(df)
    if "Código de Expediente" in str(df.iloc[0]):
        Expediente = df["Código de Expediente"]
        del df["Código de Expediente"]
        df.insert(1, "Código de Expediente", Expediente)
    
    #print(df)
    
    return df

# %%
for i in range(len(salida)):
    print(i)
    print(SOLICITUDES[i])
    tabla = pd.read_excel(SOLICITUDES[i])
    
    #print(tabla)
    contador = 0
   
    for j in tabla.iloc[:,0]:
        
        if "\n" in str(j):
            j = str(j).replace("\n","")
        #print(j)
        if "N°" in str(j) or "Número" in str(j) or "Numero" in str(j):
            
            new_header = tabla.iloc[contador]
            tabla = tabla[contador+1:]
            tabla.columns = new_header
           
            break
        contador = contador + 1
            
        
    
    df = verificarColumnas(tabla, "SOLICITUDES_INGRESADAS_EN_OCTUBRE_DE_2018.xls")
    
    df.to_excel("Datos Solicitudes/Datos Solicitudes Parciales/"+SOLICITUDES[i], index = False)
    print("########################### DIVISION ######################")

# %%
file1 = "Datos Solicitudes Parciales/*.xls"
for item in file1:
    files = glob.glob(file1)
    df = pd.DataFrame()
    for file in files:
        df = df.append(pd.read_excel(file), ignore_index=True)
    
for i in df.columns:

    for j in df.columns:

        b = i
        if i.lower().replace("á", "a").replace("é","e").replace("í","i").replace("ó","o").replace("ú","u").replace("\n","") == j.lower().replace("á", "a").replace("é","e").replace("í","i").replace("ó","o").replace("ú","u").replace("\n",""):
            
            b = b.replace("\n","")
            df.rename(columns = {str(j) : str(b)}, inplace = True)
    if str(i) == "Desnivel":
        
        break
                
df = df.groupby(level=0, axis=1, sort = False).first()

df.drop(df.columns[34:], axis=1, inplace=True)


df.to_excel("Datos Solicitudes Consolidado.xlsx", index = False)
# Out:
# Desnivel FINAL

# %%
#DATOS DE REGISTROS DATA HIDRO

REGISTRO = []
for i in ls():
    if "REGISTRO" in i: #and "REGISTRO" not in i:
        REGISTRO.append(i)
    if "registro" in i: #and "registro" not in i:
        REGISTRO.append(i)
        
REGISTRO
# Out:
# ['REGISTRO-CBR-DERECHOS-NC-CONCEDIDOS-EN-EL-MES-DE-ABRIL-2016.xls',
#  'REGISTRO-CBR-DERECHOS-NC-CONCEDIDOS-EN-EL-MES-DE-DICIEMBRE-2013.xls',
#  'REGISTRO-CBR-DERECHOS-NC-CONCEDIDOS-EN-EL-MES-DE-NOVIEMBRE-2016.xls',
#  'REGISTRO-CBR-DERECHOS-NC-CONCEDIDOS-EN-EL-MES-DE-SEPTIEMBRE-2016.xls',
#  'REGISTRO-CBR-DERECHOS-NC-CONCEDIDOS-MES-DE-AGOSTO-2016.xls',
#  'registros_cbr_derechos_nc_sep2015.xls',
#  'REGISTRO_CBR_abril2015.xls',
#  'REGISTRO_CBR_DERECHOS-NC-CONCEDIDOS-EN-EL-MES-DE-OCTUBRE-2014.xls',
#  'REGISTRO_CBR_DERECHOS_NC_CONCEDIDOSC%C3%8C%C2%A7_MES_DE_MAYO_2016.xls',
#  'REGISTRO_CBR_DERECHOS_NC_CONCEDIDOS_EN_EL_MES_DE_ABRIL_2013.xls',
#  'REGISTRO_CBR_DERECHOS_NC_CONCEDIDOS_EN_EL_MES_DE_ABRIL_2017.xls',
#  'REGISTRO_CBR_DERECHOS_NC_CONCEDIDOS_EN_EL_MES_DE_ABRIL_DE_2018.xls',
#  'REGISTRO_CBR_DERECHOS_NC_CONCEDIDOS_EN_EL_MES_DE_ABRIL_DE_2019.xls',
#  'REGISTRO_CBR_DERECHOS_NC_CONCEDIDOS_EN_EL_MES_DE_ABRIL_DE_2020.xls',
#  'REGISTRO_CBR_DERECHOS_NC_CONCEDIDOS_EN_EL_MES_DE_AGOSTO_2013.xls',
#  'REGISTRO_CBR_DERECHOS_NC_CONCEDIDOS_EN_EL_MES_DE_AGOSTO_2014.xls',
#  'REGISTRO_CBR_DERECHOS_NC_CONCEDIDOS_EN_EL_MES_DE_AGOSTO_2015.xls',
#  'REGISTRO_CBR_DERECHOS_NC_CONCEDIDOS_EN_EL_MES_DE_AGOSTO_2017.xls',
#  'REGISTRO_CBR_DERECHOS_NC_CONCEDIDOS_EN_EL_MES_DE_AGOSTO_DE_2018.xls',
#  'REGISTRO_CBR_DERECHOS_NC_CONCEDIDOS_EN_EL_MES_DE_AGOSTO_DE_2019.xls',
#  'REGISTRO_CBR_DERECHOS_NC_CONCEDIDOS_EN_EL_MES_DE_AGOSTO_DE_2020.xls',
#  'REGISTRO_CBR_DERECHOS_NC_CONCEDIDOS_EN_EL_MES_DE_DICIEMBRE_2015.xls',
#  'REGISTRO_CBR_DERECHOS_NC_CONCEDIDOS_EN_EL_MES_DE_DICIEMBRE_2016_WR_SEY.xls',
#  'REGISTRO_CBR_DERECHOS_NC_CONCEDIDOS_EN_EL_MES_DE_DICIEMBRE_2017.xls',
#  'REGISTRO_CBR_DERECHOS_NC_CONCEDIDOS_EN_EL_MES_DE_DICIEMBRE_DE_2018.xls',
#  'REGISTRO_CBR_DERECHOS_NC_CONCEDIDOS_EN_EL_MES_DE_DICIEMBRE_DE_2019.xls',
#  'REGISTRO_CBR_DERECHOS_NC_CONCEDIDOS_EN_EL_MES_DE_ENERO_2013.xls',
#  'REGISTRO_CBR_DERECHOS_NC_CONCEDIDOS_EN_EL_MES_DE_ENERO_2015.xls',
#  'REGISTRO_CBR_DERECHOS_NC_CONCEDIDOS_EN_EL_MES_DE_ENERO_2017.xls',
#  'REGISTRO_CBR_DERECHOS_NC_CONCEDIDOS_EN_EL_MES_DE_ENERO_DE_2018.xls',
#  'REGISTRO_CBR_DERECHOS_NC_CONCEDIDOS_EN_EL_MES_DE_ENERO_DE_2020.xls',
#  'REGISTRO_CBR_DERECHOS_NC_CONCEDIDOS_EN_EL_MES_DE_FEBRERO_2013.xls',
#  'REGISTRO_CBR_DERECHOS_NC_CONCEDIDOS_EN_EL_MES_DE_FEBRERO_2015.xls',
#  'REGISTRO_CBR_DERECHOS_NC_CONCEDIDOS_EN_EL_MES_DE_FEBRERO_2017.xls',
#  'REGISTRO_CBR_DERECHOS_NC_CONCEDIDOS_EN_EL_MES_DE_FEBRERO_DE_2018.xls',
#  'REGISTRO_CBR_DERECHOS_NC_CONCEDIDOS_EN_EL_MES_DE_FEBRERO_DE_2019.xls',
#  'REGISTRO_CBR_DERECHOS_NC_CONCEDIDOS_EN_EL_MES_DE_FEBRERO_DE_2020.xls',
#  'REGISTRO_CBR_DERECHOS_NC_CONCEDIDOS_EN_EL_MES_DE_JULIO_2013.xls',
#  'REGISTRO_CBR_DERECHOS_NC_CONCEDIDOS_EN_EL_MES_DE_JULIO_2014.xls',
#  'REGISTRO_CBR_DERECHOS_NC_CONCEDIDOS_EN_EL_MES_DE_JULIO_2017.xls',
#  'REGISTRO_CBR_DERECHOS_NC_CONCEDIDOS_EN_EL_MES_DE_JULIO_DE_2018.xls',
#  'REGISTRO_CBR_DERECHOS_NC_CONCEDIDOS_EN_EL_MES_DE_JULIO_DE_2019.xls',
#  'REGISTRO_CBR_DERECHOS_NC_CONCEDIDOS_EN_EL_MES_DE_JULIO_DE_2020.xls',
#  'REGISTRO_CBR_DERECHOS_NC_CONCEDIDOS_EN_EL_MES_DE_JUNIO_2014.xls',
#  'REGISTRO_CBR_DERECHOS_NC_CONCEDIDOS_EN_EL_MES_DE_JUNIO_2015.xls',
#  'REGISTRO_CBR_DERECHOS_NC_CONCEDIDOS_EN_EL_MES_DE_JUNIO_2016.xls',
#  'REGISTRO_CBR_DERECHOS_NC_CONCEDIDOS_EN_EL_MES_DE_JUNIO_2017.xls',
#  'REGISTRO_CBR_DERECHOS_NC_CONCEDIDOS_EN_EL_MES_DE_JUNIO_DE_2018.xls',
#  'REGISTRO_CBR_DERECHOS_NC_CONCEDIDOS_EN_EL_MES_DE_JUNIO_DE_2019.xls',
#  'REGISTRO_CBR_DERECHOS_NC_CONCEDIDOS_EN_EL_MES_DE_JUNIO_DE_2020.xls',
#  'REGISTRO_CBR_DERECHOS_NC_CONCEDIDOS_EN_EL_MES_DE_MARZO_2013.xls',
#  'REGISTRO_CBR_DERECHOS_NC_CONCEDIDOS_EN_EL_MES_DE_MARZO_2017.xls',
#  'REGISTRO_CBR_DERECHOS_NC_CONCEDIDOS_EN_EL_MES_DE_MARZO_DE_2018.xls',
#  'REGISTRO_CBR_DERECHOS_NC_CONCEDIDOS_EN_EL_MES_DE_MARZO_DE_2019.xls',
#  'REGISTRO_CBR_DERECHOS_NC_CONCEDIDOS_EN_EL_MES_DE_MARZO_DE_2020.xls',
#  'REGISTRO_CBR_DERECHOS_NC_CONCEDIDOS_EN_EL_MES_DE_MAYO_2013.xls',
#  'REGISTRO_CBR_DERECHOS_NC_CONCEDIDOS_EN_EL_MES_DE_MAYO_2014.xls',
#  'REGISTRO_CBR_DERECHOS_NC_CONCEDIDOS_EN_EL_MES_DE_MAYO_2017.xls',
#  'REGISTRO_CBR_DERECHOS_NC_CONCEDIDOS_EN_EL_MES_DE_MAYO_DE_2018.xls',
#  'REGISTRO_CBR_DERECHOS_NC_CONCEDIDOS_EN_EL_MES_DE_MAYO_DE_2019.xls',
#  'REGISTRO_CBR_DERECHOS_NC_CONCEDIDOS_EN_EL_MES_DE_MAYO_DE_2020_(1).xls',
#  'REGISTRO_CBR_DERECHOS_NC_CONCEDIDOS_EN_EL_MES_DE_NOVIEMBRE_2013.xls',
#  'REGISTRO_CBR_DERECHOS_NC_CONCEDIDOS_EN_EL_MES_DE_NOVIEMBRE_2014.xls',
#  'REGISTRO_CBR_DERECHOS_NC_CONCEDIDOS_EN_EL_MES_DE_NOVIEMBRE_2015.xls',
#  'REGISTRO_CBR_DERECHOS_NC_CONCEDIDOS_EN_EL_MES_DE_NOVIEMBRE_2017.xls',
#  'REGISTRO_CBR_DERECHOS_NC_CONCEDIDOS_EN_EL_MES_DE_NOVIEMBRE_DE_2018.xls',
#  'REGISTRO_CBR_DERECHOS_NC_CONCEDIDOS_EN_EL_MES_DE_NOVIEMBRE_DE_2019.xls',
#  'REGISTRO_CBR_DERECHOS_NC_CONCEDIDOS_EN_EL_MES_DE_OCTUBRE_2013.xls',
#  'REGISTRO_CBR_DERECHOS_NC_CONCEDIDOS_EN_EL_MES_DE_OCTUBRE_2015.xls',
#  'REGISTRO_CBR_DERECHOS_NC_CONCEDIDOS_EN_EL_MES_DE_OCTUBRE_2016.xls',
#  'REGISTRO_CBR_DERECHOS_NC_CONCEDIDOS_EN_EL_MES_DE_OCTUBRE_2017.xls',
#  'REGISTRO_CBR_DERECHOS_NC_CONCEDIDOS_EN_EL_MES_DE_OCTUBRE_DE_2018.xls',
#  'REGISTRO_CBR_DERECHOS_NC_CONCEDIDOS_EN_EL_MES_DE_OCTUBRE_DE_2019.xls',
#  'REGISTRO_CBR_DERECHOS_NC_CONCEDIDOS_EN_EL_MES_DE_SEPTIEMBRE_2013.xls',
#  'REGISTRO_CBR_DERECHOS_NC_CONCEDIDOS_EN_EL_MES_DE_SEPTIEMBRE_2014.xls',
#  'REGISTRO_CBR_DERECHOS_NC_CONCEDIDOS_EN_EL_MES_DE_SEPTIEMBRE_2017.xls',
#  'REGISTRO_CBR_DERECHOS_NC_CONCEDIDOS_EN_EL_MES_DE_SEPTIEMBRE_DE_2018.xls',
#  'REGISTRO_CBR_DERECHOS_NC_CONCEDIDOS_EN_EL_MES_DE_SEPTIEMBRE_DE_2019.xls',
#  'REGISTRO_CBR_DERECHOS_NC_CONCEDIDOS_EN_EL_MES_DE_SEPTIEMBRE_DE_2020.xls',
#  'REGISTRO_CBR_DERECHOS_NC_CONCEDIDOS_MES_DE_DICIEMBRE_DE_2012.xls',
#  'REGISTRO_CBR_DERECHOS_NC_CONCEDIDOS_MES_DE_ENERO_2016.xls',
#  'REGISTRO_CBR_DERECHOS_NC_CONCEDIDOS_MES_DE_FEBRERO_2016.xls',
#  'REGISTRO_CBR_DERECHOS_NC_CONCEDIDOS_MES_DE_MARZO_2016.xls',
#  'REGISTRO_CBR_DERECHOS_NC_CONCEDIDOS_MES_DE_NOVIEMBRE_2012.xls',
#  'REGISTRO_CBR_DERECHOS_NC_CONCEDIDOS_MES_DE_OCTUBRE_2012.xls',
#  'REGISTRO_CBR_DERECHOS_NC_CONSTITUIDOS_EN_JULIO_2016.xls',
#  'REGISTRO_CBR_DERECHOS_NC_RECIBIDOS_EN_EL_MES_DE_JUNIO_2013.xls',
#  'REGISTRO_CBR_DERECHOS_NC_RECIBIDOS_MES_DE_AGOSTO_2012.xls',
#  'REGISTRO_CBR_DERECHOS_NC_RECIBIDOS_MES_DE_JULIO_2012.xls',
#  'REGISTRO_CBR_DERECHOS_NC_RECIBIDOS_MES_DE_SEPTIEMBRE_2012.xls',
#  'REGISTRO_CBR_DE_DERECHOS_NC_RECIBIDOS_EN_EL_MES_DE_MAYO_2012.xls',
#  'REGISTRO_CBR_DE_DERECHOS_NC_RECIBIDOS_MES_DE_ABRIL_2012.xls',
#  'REGISTRO_CBR_DE_DERECHOS_NC_RECIBIDOS_MES_DE_JUNIO_2012.xls',
#  'REGISTRO_CBR_DE_DERECHOS_NC_RECIBIDOS_MES_DICIEMBRE_2011.xls',
#  'REGISTRO_CBR_DE_DERECHOS_NC_RECIBIDOS_MES_ENERO_2012.xls',
#  'REGISTRO_CBR_JULIO_2015.xls',
#  'REGISTRO_CBR_NC_CONCEDIDOS_EN_EL_MES_DE_ENERO_DE_2019.xls',
#  'REGISTRO_CBR__marzo2015.xls']

# %%
final = pd.DataFrame()
lista = []
unico = True
for n in REGISTRO:
    if n != "REGISTRO_CBR_DERECHOS_NC_CONCEDIDOSC%C3%8C%C2%A7_MES_DE_MAYO_2016.xls" and n != "REGISTRO_CBR_DERECHOS_NC_CONCEDIDOS_EN_EL_MES_DE_ABRIL_DE_2020.xls" and n != "REGISTRO_CBR_DERECHOS_NC_CONCEDIDOS_MES_DE_ENERO_2016.xls" and n != "REGISTRO_CBR_DERECHOS_NC_CONCEDIDOSC%C3%8C%C2%A7_MES_DE_MAYO_2016.xls":
        print(n) 
        df = pd.read_excel(n)
        contador = 1
        valido = False
        for j in df.iloc[:,0]:
            #print(j)
            if "REGION" in str(j) or "REGIÓN" in str(j) or "NÚMERO" in str(j) or "NUMERO" in str(j) :
                valido = True
                break
            contador = contador + 1
        print(contador)
        if valido == True:
            df = pd.read_excel(n, header=[0,1], skiprows=contador)
        else:
            df = pd.read_excel(n, header=[0,1])

        
        ref = df.columns[0]
        for i in df.columns:
            print(i)
            if "NUMERO" in i[0]:
                del df["NUMERO","Unnamed: 0_level_1"]
            if 'Unnamed: 0_level_0' in i[0]:
                del df["Unnamed: 0_level_0", "Unnamed: 0_level_1"]
            i0 = i[0].replace("\n"," ")
            i1 = i[1].replace("\n"," ")
            df.rename(columns = {i[1]:i1,i[0]:i0 }, inplace=True)
            if i[1].startswith("Unnamed"):

                df.rename(columns = {i[1]:""}, inplace=True)
        df = df.loc[:,~df.columns.duplicated()]        
        for i in df.columns:
            if unico == True:
                lista.append(i[0]+ " "+ i[1])
            
        #df = df[2:]
        
        unico = False
        df.columns = lista   
        #print(df)
        df = df.dropna(how='all')
        df.to_excel("Datos Registros/Datos Registros Parciales/"+n, index = False)
        
        print(df["REGISTRO ACTUAL REGISTRO AÑO"])    
        #df = df.reindex(df.columns, axis=1)
        final = final.append(df, ignore_index=True)
        
        
#final = final.reindex(df.columns, axis=1)

final.insert(0, 'NÚMERO', range(1, 1 + len(final)))
final.to_excel("Datos Registros/Datos Registros Consolidado.xlsx", index= False)
# Out:
# REGISTRO-CBR-DERECHOS-NC-CONCEDIDOS-EN-EL-MES-DE-ABRIL-2016.xls
# 59
# ('NUMERO', 'Unnamed: 0_level_1')
# ('REGIÓN', 'Unnamed: 1_level_1')
# ('LUGAR CBR', 'Unnamed: 2_level_1')
# ('REGISTRO ACTUAL', 'REGISTRO\nAÑO')
# ('REGISTRO ACTUAL', 'NUMERO')
# ('REGISTRO ACTUAL', 'FOJAS')
# ('TIPO TRANSACCION', 'Unnamed: 6_level_1')
# ('FECHA DE INSCRIPCION EN EL CBR', 'Unnamed: 7_level_1')
# ('DATOS VENDEDOR', 'RUT VENDEDOR')
# ('DATOS VENDEDOR', 'NOMBRE VENDEDOR')
# ('REGISTRO ANTERIOR', 'REGISTRO\nAÑO')
# ('REGISTRO ANTERIOR', 'NUMERO')
# ('REGISTRO ANTERIOR', 'FOJAS')
# ('DATOS COMPRADOR', 'RUT\nCOMPRADOR')
# ('DATOS COMPRADOR', 'NOMBRE COMPRADOR')
# ('NATURALEZA', 'Unnamed: 15_level_1')
# ('CAUDAL ', 'Unnamed: 16_level_1')
# ('UNIDAD\n CAUDAL', 'Unnamed: 17_level_1')
# ('TIPO \nDERECHO', 'Unnamed: 18_level_1')
# ('EJERCICIO', 'Unnamed: 19_level_1')
# ('FUENTE', 'Unnamed: 20_level_1')
# ('VALOR \nTRANSACCION', 'Unnamed: 21_level_1')
# ('UNIDAD', 'Unnamed: 22_level_1')
# ('OBSERVACIÓN', 'Unnamed: 23_level_1')
# ('OBSERVACIÓN', 'Unnamed: 24_level_1')
# 0     2016.0
# 1     2016.0
# 2     2016.0
# 3     2016.0
# 4     2016.0
# 5     2016.0
# 6     2016.0
# 7     2016.0
# 8     2016.0
# 9     2016.0
# 10    2016.0
# 11    2016.0
# 12    2016.0
# 13    2016.0
# 14    2016.0
# 15    2016.0
# 16    2016.0
# 17    2016.0
# 18    2016.0
# 19    2016.0
# 20    2016.0
# 21    2016.0
# 22    2016.0
# 23    2016.0
# 24    2015.0
# 25    2015.0
# 26    2016.0
# 27    2016.0
# 28    2016.0
# 29    2016.0
# 30    2016.0
# 31    2016.0
# 32    2016.0
# 33    2016.0
# 34    2016.0
# 35    2016.0
# 36    2016.0
# 37    2016.0
# 38    2016.0
# 39    2016.0
# 40    2016.0
# 41    2016.0
# 42    2016.0
# 43    2016.0
# 44    2016.0
# 45    2016.0
# 46    2016.0
# 47    2016.0
# 48    2016.0
# 49    2016.0
# 56       NaN
# Name: REGISTRO ACTUAL REGISTRO AÑO, dtype: float64
# REGISTRO-CBR-DERECHOS-NC-CONCEDIDOS-EN-EL-MES-DE-DICIEMBRE-2013.xls
# 4
# ('NUMERO', 'Unnamed: 0_level_1')
# ('REGIÓN', 'Unnamed: 1_level_1')
# ('LUGAR CBR', 'Unnamed: 2_level_1')
# ('REGISTRO ACTUAL', 'REGISTRO\nAÑO')
# ('REGISTRO ACTUAL', 'NUMERO')
# ('REGISTRO ACTUAL', 'FOJAS')
# ('TIPO TRANSACCION', 'Unnamed: 6_level_1')
# ('FECHA DE INSCRIPCION EN EL CBR', 'Unnamed: 7_level_1')
# ('DATOS VENDEDOR', 'RUT VENDEDOR')
# ('DATOS VENDEDOR', 'NOMBRE VENDEDOR')
# ('REGISTRO ANTERIOR', 'REGISTRO\nAÑO')
# ('REGISTRO ANTERIOR', 'NUMERO')
# ('REGISTRO ANTERIOR', 'FOJAS')
# ('DATOS COMPRADOR', 'RUT\nCOMPRADOR')
# ('DATOS COMPRADOR', 'NOMBRE COMPRADOR')
# ('NATURALEZA', 'Unnamed: 15_level_1')
# ('CAUDAL ', 'Unnamed: 16_level_1')
# ('UNIDAD\n CAUDAL', 'Unnamed: 17_level_1')
# ('TIPO \nDERECHO', 'Unnamed: 18_level_1')
# ('EJERCICIO', 'Unnamed: 19_level_1')
# ('FUENTE', 'Unnamed: 20_level_1')
# ('VALOR \nTRANSACCION', 'Unnamed: 21_level_1')
# ('UNIDAD', 'Unnamed: 22_level_1')
# ('OBSERVACIÓN', 'Unnamed: 23_level_1')
# 0     
# 25    2015.0
# 26    2015.0
# 27    2015.0
# 28    2015.0
# 29    2015.0
# 30    2015.0
# 31    2015.0
# 32    2014.0
# 33    2015.0
# 34    2015.0
# 35    2015.0
# 80       NaN
# 81       NaN
# 82       NaN
# 83       NaN
# 84       NaN
# 85       NaN
# 86       NaN
# 87       NaN
# 88       NaN
# 89       NaN
# 90       NaN
# 91       NaN
# 92       NaN
# Name: REGISTRO ACTUAL REGISTRO AÑO, dtype: float64
# REGISTRO_CBR_DERECHOS-NC-CONCEDIDOS-EN-EL-MES-DE-OCTUBRE-2014.xls
# 36
# ('NUMERO', 'Unnamed: 0_level_1')
# ('REGIÓN', 'Unnamed: 1_level_1')
# ('LUGAR CBR', 'Unnamed: 2_level_1')
# ('REGISTRO ACTUAL', 'REGISTRO\nAÑO')
# ('REGISTRO ACTUAL', 'NUMERO')
# ('REGISTRO ACTUAL', 'FOJAS')
# ('TIPO TRANSACCION', 'Unnamed: 6_level_1')
# ('FECHA DE INSCRIPCION EN EL CBR', 'Unnamed: 7_level_1')
# ('DATOS VENDEDOR', 'RUT VENDEDOR')
# ('DATOS VENDEDOR', 'NOMBRE VENDEDOR')
# ('REGISTRO ANTERIOR', 'REGISTRO\nAÑO')
# ('REGISTRO ANTERIOR', 'NUMERO')
# ('REGISTRO ANTERIOR', 'FOJAS')
# ('DATOS COMPRADOR', 'RUT\nCOMPRADOR')
# ('DATOS COMPRADOR', 'NOMBRE COMPRADOR')
# ('NATURALEZA', 'Unnamed: 15_level_1')
# ('CAUDAL ', 'Unnamed: 16_level_1')
# ('UNIDAD\n CAUDAL', 'Unnamed: 17_level_1')
# ('TIPO \nDERECHO', 'Unnamed: 18_level_1')
# ('EJERCICIO', 'Unnamed: 19_level_1')
# ('FUENTE', 'Unnamed: 20_level_1')
# ('VALOR \nTRANSACCION', 'Unnamed: 21_level_1')
# ('UNIDAD', 'Unnamed: 22_level_1')
# ('OBSERVACIÓN', 'Unnamed: 23_level_1')
# 0     2014
# 1     2014
# 2     2014
# 3     2014
# 4     2014
# 5     2014
# 6     2014
# 7     2014
# 8     2014
# 9     2014
# 10    2014
# 11    2014
# 12    2014
# 13    2014
# 14    2014
# 15    2014
# 16    2014
# 17    2014
# 18    2014
# 19    2014
# 20    2014
# 21    2014
# 22    2014
# 23    2014
# 24    2014
# 25    2014
# 26    2014
# 27    2014
# 28    2014
# 29    2014
# 30    2014
# 31    2014
# 32    2014
# 33    2014
# Name: REGISTRO ACTUAL REGISTRO AÑO, dtype: int64
# REGISTRO_CBR_DERECHOS_NC_CONCEDIDOS_EN_EL_MES_DE_ABRIL_2013.xls
# 28
# ('NUMERO', 'Unnamed: 0_level_1')
# ('REGIÓN', 'Unnamed: 1_level_1')
# ('LUGAR CBR', 'Unnamed: 2_level_1')
# ('REGISTRO ACTUAL', 'REGISTRO\nAÑO')
# ('REGISTRO ACTUAL', 'NUMERO')
# ('REGISTRO ACTUAL', 'FOJAS')
# ('TIPO TRANSACCION', 'Unnamed: 6_level_1')
# ('FECHA DE INSCRIPCION EN EL CBR', 'Unnamed: 7_level_1')
# ('DATOS VENDEDOR', 'RUT\nVENDEDOR')
# ('DATOS VENDEDOR', 'NOMBRE VENDEDOR')
# ('REGISTRO ANTERIOR', 'REGISTRO\nAÑO')
# ('REGISTRO ANTERIOR', 'NUMERO')
# ('REGISTRO ANTERIOR', 'FOJAS')
# ('DATOS COMPRADOR', 'RUT\nCOMPRADOR')
# ('DATOS COMPRADOR', 'NOMBRE COMPRADOR')
# ('NATURALEZA', 'Unnamed: 15_level_1')
# ('CAUDAL ', 'Unnamed: 16_level_1')
# ('UNIDAD\n CAUDAL', 'Unnamed: 17_level_1')
# ('TIPO \nDERECHO', 'Unnamed: 18_level_1')
# ('EJERCICIO', 'Unnamed: 19_level_1')
# ('FUENTE', 'Unnamed: 20_level_1')
# ('VALOR \nTRANSACCION', 'Unnamed: 21_level_1')
# ('UNIDAD', 'Unnamed: 22_level_1')
# ('OBSERVACIÓN', 'Unnamed: 23_level_1')
# 0     2013
# 1     2013
# 2     2013
# 3     2013
# 4     2013
# 5     2013
# 6     2013
# 7     2013
# 8     2013
# 9     2013
# 10    2013
# 11    2013
# 12    2013
# 13    2013
# 14    2013
# 15    2013
# 16    2013
# 17    2013
# 18    2013
# 19    2013
# 20    2013
# 21    2013
# 22    2013
# 23    2013
# 24    2013
# 25    2013
# Name: REGISTRO ACTUAL REGISTRO AÑO, dtype: int64
# REGISTRO_CBR_DERECHOS_NC_CONCEDIDOS_EN_EL_MES_DE_ABRIL_2017.xls
# 17
# ('NUMERO', 'Unnamed: 0_level_1')
# ('REGIÓN', 'Unnamed: 1_level_1')
# ('LUGAR CBR', 'Unnamed: 2_level_1')
# ('REGISTRO ACTUAL', 'REGISTRO\nAÑO')
# ('REGISTRO ACTUAL', 'NUMERO')
# ('REGISTRO ACTUAL', 'FOJAS')
# ('TIPO TRANSACCION', 'Unnamed: 6_level_1')
# ('FECHA DE INSCRIPCION EN EL CBR', 'Unnamed: 7_level_1')
# ('DATOS VENDEDOR', 'RUT VENDEDOR')
# ('DATOS VENDEDOR', 'NOMBRE VENDEDOR')
# ('REGISTRO ANTERIOR', 'REGISTRO\nAÑO')
# ('REGISTRO ANTERIOR', 'NUMERO')
# ('REGISTRO ANTERIOR', 'FOJAS')
# ('DATOS COMPRADOR', 'RUT\nCOMPRADOR')
# ('DATOS COMPRADOR', 'NOMBRE COMPRADOR')
# ('NATURALEZA', 'Unnamed: 15_level_1')
# ('CAUDAL ', 'Unnamed: 16_level_1')
# ('UNIDAD\n CAUDAL', 'Unnamed: 17_level_1')
# ('TIPO \nDERECHO', 'Unnamed: 18_level_1')
# ('PER', 'Unnamed: 19_level_1')
# ('FUENTE', 'Unnamed: 20_level_1')
# ('VALOR \nTRANSACCION', 'Unnamed: 21_level_1')
# ('UNIDAD', 'Unnamed: 22_level_1')
# ('OBSERVACIÓN', 'Unnamed: 23_level_1')
# 0     2017
# 1     2017
# 2     2017
# 3     2017
# 4     2016
# 5     2017
# 6     2017
# 7     2017
# 8     2017
# 9     2017
# 10    2017
# 11    2017
# 12    2017
# 13    2017
# 14    2017
# Name: REGISTRO ACTUAL REGISTRO AÑO, dtype: int64
# REGISTRO_CBR_DERECHOS_NC_CONCEDIDOS_EN_EL_MES_DE_ABRIL_DE_2018.xls
# 22
# ('NUMERO', 'Unnamed: 0_level_1')
# ('REGIÓN', 'Unnamed: 1_level_1')
# ('LUGAR CBR', 'Unnamed: 2_level_1')
# ('REGISTRO ACTUAL', 'REGISTRO\nAÑO')
# ('REGISTRO ACTUAL', 'NUMERO')
# ('REGISTRO ACTUAL', 'FOJAS')
# ('TIPO TRANSACCION', 'Unnamed: 6_level_1')
# ('FECHA DE INSCRIPCION EN EL CBR', 'Unnamed: 7_level_1')
# ('DATOS VENDEDOR', 'RUT VENDEDOR')
# ('DATOS VENDEDOR', 'NOMBRE VENDEDOR')
# ('REGISTRO ANTERIOR', 'REGISTRO\nAÑO')
# ('REGISTRO ANTERIOR', 'NUMERO')
# ('REGISTRO ANTERIOR', 'FOJAS')
# ('DATOS COMPRADOR', 'RUT\nCOMPRADOR')
# ('DATOS COMPRADOR', 'NOMBRE COMPRADOR')
# ('NATURALEZA', 'Unnamed: 15_level_1')
# ('CAUDAL ', 'Unnamed: 16_level_1')
# ('UNIDAD\n CAUDAL', 'Unnamed: 17_level_1')
# ('TIPO \nDERECHO', 'Unnamed: 18_level_1')
# ('EJERCICIO', 'Unnamed: 19_level_1')
# ('FUENTE', 'Unnamed: 20_level_1')
# ('VALOR \nTRANSACCION', 'Unnamed: 21_level_1')
# ('UNIDAD', 'Unnamed: 22_level_1')
# ('OBSERVACIÓN', 'Unnamed: 23_level_1')
# 0     2018
# 1     2018
# 2     2018
# 3     2018
# 4     2018
# 5     2018
# 6     2018
# 7     2018
# 8     2018
# 9     2018
# 10    2018
# 11    2018
# 12    2018
# 13    2018
# 14    2018
# 15    2018
# 16    2018
# 17    2018
# 18    2018
# 19    2018
# Name: REGISTRO ACTUAL REGISTRO AÑO, dtype: int64
# REGISTRO_CBR_DERECHOS_NC_CONCEDIDOS_EN_EL_MES_DE_ABRIL_DE_2019.xls
# 18
# ('NUMERO', 'Unnamed: 0_level_1')
# ('REGIÓN', 'Unnamed: 1_level_1')
# ('LUGAR CBR', 'Unnamed: 2_level_1')
# ('REGISTRO ACTUAL', 'REGISTRO\nAÑO')
# ('REGISTRO ACTUAL', 'NUMERO')
# ('REGISTRO ACTUAL', 'FOJAS')
# ('TIPO TRANSACCION', 'Unnamed: 6_level_1')
# ('FECHA DE INSCRIPCION EN EL CBR', 'Unnamed: 7_level_1')
# ('DATOS VENDEDOR', 'RUT VENDEDOR')
# ('DATOS VENDEDOR', 'NOMBRE VENDEDOR')
# ('REGISTRO ANTERIOR', 'REGISTRO\nAÑO')
# ('REGISTRO ANTERIOR', 'NUMERO')
# ('REGISTRO ANTERIOR', 'FOJAS')
# ('DATOS COMPRADOR', 'RUT\nCOMPRADOR')
# ('DATOS COMPRADOR', 'NOMBRE COMPRADOR')
# ('NATURALEZA', 'Unnamed: 15_level_1')
# ('CAUDAL ', 'Unnamed: 16_level_1')
# ('UNIDAD\n CAUDAL', 'Unnamed: 17_level_1')
# ('TIPO \nDERECHO', 'Unnamed: 18_level_1')
# ('PER', 'Unnamed: 19_level_1')
# ('FUENTE', 'Unnamed: 20_level_1')
# ('VALOR \nTRANSACCION', 'Unnamed: 21_level_1')
# ('UNIDAD', 'Unnamed: 22_level_1')
# ('OBSERVACIÓN', 'Unnamed: 23_level_1')
# 0     2019
# 1     2019
# 2     2019
# 3     2019
# 4     2019
# 5     2019
# 6     2019
# 7     2019
# 8     2019
# 9     2019
# 10    2019
# 11    2019
# 12    2019
# 13    2019
# 14    2019
# 15    2019
# Name: REGISTRO ACTUAL REGISTRO AÑO, dtype: int64
# REGISTRO_CBR_DERECHOS_NC_CONCEDIDOS_EN_EL_MES_DE_AGOSTO_2013.xls
# 5
# ('NUMERO', 'Unnamed: 0_level_1')
# ('REGIÓN', 'Unnamed: 1_level_1')
# ('LUGAR CBR', 'Unnamed: 2_level_1')
# ('REGISTRO ACTUAL', 'REGISTRO\nAÑO')
# ('REGISTRO ACTUAL', 'NUMERO')
# ('REGISTRO ACTUAL', 'FOJAS')
# ('TIPO TRANSACCION', 'Unnamed: 6_level_1')
# ('FECHA DE INSCRIPCION EN EL CBR', 'Unnamed: 7_level_1')
# ('DATOS VENDEDOR', 'RUT VENDEDOR')
# ('DATOS VENDEDOR', 'NOMBRE VENDEDOR')
# ('REGISTRO ANTERIOR', 'REGISTRO\nAÑO')
# ('REGISTRO ANTERIOR', 'NUMERO')
# ('REGISTRO ANTERIOR', 'FOJAS')
# ('DATOS COMPRADOR', 'RUT\nCOMPRADOR')
# ('DATOS COMPRADOR', 'NOMBRE COMPRADOR')
# ('NATURALEZA', 'Unnamed: 15_level_1')
# ('CAUDAL ', 'Unnamed: 16_level_1')
# ('UNIDAD\n CAUDAL', 'Unnamed: 17_level_1')
# ('TIPO \nDERECHO', 'Unnamed: 18_level_1')
# ('EJERCICIO', 'Unnamed: 19_level_1')
# ('FUENTE', 'Unnamed: 20_level_1')
# ('VALOR \nTRANSACCION', 'Unnamed: 21_level_1')
# ('UNIDAD', 'Unnamed: 22_level_1')
# ('OBSERVACIÓN', 'Unnamed: 23_level_1')
# 0     2013
# 1     2013
# 2     2013
# 3     2013
# 4     2013
#       ...
# 59    2012
# 60    2012
# 61    2013
# 62    2013
# 63    2013
# Name: REGISTRO ACTUAL REGISTRO AÑO, Length: 64, dtype: int64
# REGISTRO_CBR_DERECHOS_NC_CONCEDIDOS_EN_EL_MES_DE_AGOSTO_2014.xls
# 87
# ('NUMERO', 'Unnamed: 0_level_1')
# ('REGIÓN', 'Unnamed: 1_level_1')
# ('LUGAR CBR', 'Unnamed: 2_level_1')
# ('REGISTRO ACTUAL', 'REGISTRO\nAÑO')
# ('REGISTRO ACTUAL', 'NUMERO')
# ('REGISTRO ACTUAL', 'FOJAS')
# ('TIPO TRANSACCION', 'Unnamed: 6_level_1')
# ('FECHA DE INSCRIPCION EN EL CBR', 'Unnamed: 7_level_1')
# ('DATOS VENDEDOR', 'RUT VENDEDOR')
# ('DATOS VENDEDOR', 'NOMBRE VENDEDOR')
# ('REGISTRO ANTERIOR', 'REGISTRO\nAÑO')
# ('REGISTRO ANTERIOR', 'NUMERO')
# ('REGISTRO ANTERIOR', 'FOJAS')
# ('DATOS COMPRADOR', 'RUT\nCOMPRADOR')
# ('DATOS COMPRADOR', 'NOMBRE COMPRADOR')
# ('NATURALEZA', 'Unnamed: 15_level_1')
# ('CAUDAL ', 'Unnamed: 16_level_1')
# ('UNIDAD\n CAUDAL', 'Unnamed: 17_level_1')
# ('TIPO \nDERECHO', 'Unnamed: 18_level_1')
# ('EJERCICIO', 'Unnamed: 19_level_1')
# ('FUENTE', 'Unnamed: 20_level_1')
# ('VALOR \nTRANSACCION', 'Unnamed: 21_level_1')
# ('UNIDAD', 'Unnamed: 22_level_1')
# ('OBSERVACIÓN', 'Unnamed: 23_level_1')
# 0     2014
# 1     2014
# 2     2014
# 3     2014
# 4     2014
#       ...
# 80    2014
# 81    2014
# 82    2014
# 83    2014
# 84    2014
# Name: REGISTRO ACTUAL REGISTRO AÑO, Length: 85, dtype: int64
# REGISTRO_CBR_DERECHOS_NC_CONCEDIDOS_EN_EL_MES_DE_AGOSTO_2015.xls
# 94
# ('NUMERO', 'Unnamed: 0_level_1')
# ('REGIÓN', 'Unnamed: 1_level_1')
# ('LUGAR CBR', 'Unnamed: 2_level_1')
# ('REGISTRO ACTUAL', 'REGISTRO\nAÑO')
# ('REGISTRO ACTUAL', 'NUMERO')
# ('REGISTRO ACTUAL', 'FOJAS')
# ('TIPO TRANSACCION', 'Unnamed: 6_level_1')
# ('FECHA DE INSCRIPCION EN EL CBR', 'Unnamed: 7_level_1')
# ('DATOS VENDEDOR', 'RUT VENDEDOR')
# ('DATOS VENDEDOR', 'NOMBRE VENDEDOR')
# ('REGISTRO ANTERIOR', 'REGISTRO\nAÑO')
# ('REGISTRO ANTERIOR', 'NUMERO')
# ('REGISTRO ANTERIOR', 'FOJAS')
# ('DATOS COMPRADOR', 'RUT\nCOMPRADOR')
# ('DATOS COMPRADOR', 'NOMBRE COMPRADOR')
# ('NATURALEZA', 'Unnamed: 15_level_1')
# ('CAUDAL ', 'Unnamed: 16_level_1')
# ('UNIDAD\n CAUDAL', 'Unnamed: 17_level_1')
# ('TIPO \nDERECHO', 'Unnamed: 18_level_1')
# ('EJERCICIO', 'Unnamed: 19_level_1')
# ('FUENTE', 'Unnamed: 20_level_1')
# ('VALOR \nTRANSACCION', 'Unnamed: 21_level_1')
# ('UNIDAD', 'Unnamed: 22_level_1')
# ('OBSERVACIÓN', 'Unnamed: 23_level_1')
# ('OBSERVACIÓN', 'Unnamed: 24_level_1')
# 0     2015.0
# 1     2015.0
# 2     2015.0
# 3     2015.0
# 4     2015.0
#        ...
# 87       NaN
# 88       NaN
# 89       NaN
# 90       NaN
# 91       NaN
# Name: REGISTRO ACTUAL REGISTRO AÑO, Length: 63, dtype: float64
# REGISTRO_CBR_DERECHOS_NC_CONCEDIDOS_EN_EL_MES_DE_AGOSTO_2017.xls
# 19
# ('NUMERO', 'Unnamed: 0_level_1')
# ('REGIÓN', 'Unnamed: 1_level_1')
# ('LUGAR CBR', 'Unnamed: 2_level_1')
# ('REGISTRO ACTUAL', 'REGISTRO\nAÑO')
# ('REGISTRO ACTUAL', 'NUMERO')
# ('REGISTRO ACTUAL', 'FOJAS')
# ('TIPO TRANSACCION', 'Unnamed: 6_level_1')
# ('FECHA DE INSCRIPCION EN EL CBR', 'Unnamed: 7_level_1')
# ('DATOS VENDEDOR', 'RUT VENDEDOR')
# ('DATOS VENDEDOR', 'NOMBRE VENDEDOR')
# ('REGISTRO ANTERIOR', 'REGISTRO\nAÑO')
# ('REGISTRO ANTERIOR', 'NUMERO')
# ('REGISTRO ANTERIOR', 'FOJAS')
# ('DATOS COMPRADOR', 'RUT\nCOMPRADOR')
# ('DATOS COMPRADOR', 'NOMBRE COMPRADOR')
# ('NATURALEZA', 'Unnamed: 15_level_1')
# ('CAUDAL ', 'Unnamed: 16_level_1')
# ('UNIDAD\n CAUDAL', 'Unnamed: 17_level_1')
# ('TIPO \nDERECHO', 'Unnamed: 18_level_1')
# ('PER', 'Unnamed: 19_level_1')
# ('FUENTE', 'Unnamed: 20_level_1')
# ('VALOR \nTRANSACCION', 'Unnamed: 21_level_1')
# ('UNIDAD', 'Unnamed: 22_level_1')
# ('OBSERVACIÓN', 'Unnamed: 23_level_1')
# 0     2017
# 1     2017
# 2     2017
# 3     2017
# 4     2017
# 5     2017
# 6     2017
# 7     2017
# 8     2017
# 9     2017
# 10    2017
# 11    2017
# 12    2017
# 13    2017
# 14    2017
# 15    2017
# 16    2017
# Name: REGISTRO ACTUAL REGISTRO AÑO, dtype: int64
# REGISTRO_CBR_DERECHOS_NC_CONCEDIDOS_EN_EL_MES_DE
DEDOR')
# ('DATOS VENDEDOR', 'NOMBRE VENDEDOR')
# ('REGISTRO ANTERIOR', 'REGISTRO\nAÑO')
# ('REGISTRO ANTERIOR', 'NUMERO')
# ('REGISTRO ANTERIOR', 'FOJAS')
# ('DATOS COMPRADOR', 'RUT\nCOMPRADOR')
# ('DATOS COMPRADOR', 'NOMBRE COMPRADOR')
# ('NATURALEZA', 'Unnamed: 15_level_1')
# ('CAUDAL ', 'Unnamed: 16_level_1')
# ('UNIDAD\n CAUDAL', 'Unnamed: 17_level_1')
# ('TIPO \nDERECHO', 'Unnamed: 18_level_1')
# ('EJERCICIO', 'Unnamed: 19_level_1')
# ('FUENTE', 'Unnamed: 20_level_1')
# ('VALOR \nTRANSACCION', 'Unnamed: 21_level_1')
# ('UNIDAD', 'Unnamed: 22_level_1')
# ('OBSERVACIÓN', 'Unnamed: 23_level_1')
# 0      2012
# 1      2012
# 2      2012
# 3      2012
# 4      2012
#        ...
# 97     2013
# 98     2013
# 99     2013
# 100    2012
# 101    2012
# Name: REGISTRO ACTUAL REGISTRO AÑO, Length: 102, dtype: int64
# REGISTRO_CBR_DERECHOS_NC_RECIBIDOS_MES_DE_AGOSTO_2012.xls
# 177
# ('REGIÓN', 'Unnamed: 0_level_1')
# ('LUGAR CBR', 'Unnamed: 1_level_1')
# ('Registro Actual', 'AÑO')
# ('Registro Actual', 'NUMERO')
# ('Registro Actual', 'FOJAS')
# ('TIPO TRANSACCION', 'Unnamed: 5_level_1')
# ('FECHA DE INSCRIPCION EN EL CBR', 'Unnamed: 6_level_1')
# ('DATOS VENDEDOR', 'RUT\nVENDEDOR')
# ('DATOS VENDEDOR', 'NOMBRE VENDEDOR')
# ('Registro Anterior', 'AÑO')
# ('Registro Anterior', 'NUMERO')
# ('Registro Anterior', 'FOJAS')
# ('DATOS COMPRADOR', 'RUT\nCOMPRADOR')
# ('DATOS COMPRADOR', 'NOMBRE COMPRADOR')
# ('NATURALEZA', 'Unnamed: 14_level_1')
# ('CAUDAL ', 'Unnamed: 15_level_1')
# ('UNIDAD\n CAUDAL', 'Unnamed: 16_level_1')
# ('TIPO \nDERECHO', 'Unnamed: 17_level_1')
# ('EJERCICIO', 'Unnamed: 18_level_1')
# ('FUENTE', 'Unnamed: 19_level_1')
# ('VALOR \nTRANSACCION TOTAL', 'Unnamed: 20_level_1')
# ('UNIDAD', 'Unnamed: 21_level_1')
# ('OBSERVACIÓN', 'Unnamed: 22_level_1')
# 0      2012
# 1      2012
# 2      2012
# 3      2012
# 4      2012
#        ...
# 170    2008
# 171    2008
# 172    2008
# 173    2012
# 174    2012
# Name: REGISTRO ACTUAL REGISTRO AÑO, Length: 175, dtype: int64
# REGISTRO_CBR_DERECHOS_NC_RECIBIDOS_MES_DE_JULIO_2012.xls
# 130
# ('REGIÓN', 'Unnamed: 0_level_1')
# ('LUGAR CBR', 'Unnamed: 1_level_1')
# ('Registro Actual', 'REGISTRO\nAÑO')
# ('Registro Actual', 'NUMERO')
# ('Registro Actual', 'FOJAS')
# ('TIPO TRANSACCION', 'Unnamed: 5_level_1')
# ('FECHA DE INSCRIPCION EN EL CBR', 'Unnamed: 6_level_1')
# ('DATOS VENDEDOR', 'RUT\nVENDEDOR')
# ('DATOS VENDEDOR', 'NOMBRE VENDEDOR')
# ('Registro Anterior', 'REGISTRO\nAÑO')
# ('Registro Anterior', 'NUMERO')
# ('Registro Anterior', 'FOJAS')
# ('DATOS COMPRADOR', 'RUT\nCOMPRADOR')
# ('DATOS COMPRADOR', 'NOMBRE COMPRADOR')
# ('NATURALEZA', 'Unnamed: 14_level_1')
# ('CAUDAL ', 'Unnamed: 15_level_1')
# ('UNIDAD\n CAUDAL', 'Unnamed: 16_level_1')
# ('TIPO \nDERECHO', 'Unnamed: 17_level_1')
# ('EJERCICIO', 'Unnamed: 18_level_1')
# ('FUENTE', 'Unnamed: 19_level_1')
# ('VALOR \nTRANSACCION TOTAL', 'Unnamed: 20_level_1')
# ('UNIDAD', 'Unnamed: 21_level_1')
# ('OBSERVACIÓN', 'Unnamed: 22_level_1')
# 0      2012
# 1      2012
# 2      2011
# 3      2011
# 4      2011
#        ...
# 123    2007
# 124    2007
# 125    2007
# 126    2007
# 127    2007
# Name: REGISTRO ACTUAL REGISTRO AÑO, Length: 128, dtype: int64
# REGISTRO_CBR_DERECHOS_NC_RECIBIDOS_MES_DE_SEPTIEMBRE_2012.xls
# 264
# ('REGIÓN', 'Unnamed: 0_level_1')
# ('LUGAR CBR', 'Unnamed: 1_level_1')
# ('Registro Actual', 'REGISTRO\nAÑO')
# ('Registro Actual', 'NUMERO')
# ('Registro Actual', 'FOJAS')
# ('TIPO TRANSACCION', 'Unnamed: 5_level_1')
# ('FECHA DE INSCRIPCION EN EL CBR', 'Unnamed: 6_level_1')
# ('DATOS VENDEDOR', 'RUT\nVENDEDOR')
# ('DATOS VENDEDOR', 'NOMBRE VENDEDOR')
# ('Registro Anterior', 'REGISTRO\nAÑO')
# ('Registro Anterior', 'NUMERO')
# ('Registro Anterior', 'FOJAS')
# ('DATOS COMPRADOR', 'RUT\nCOMPRADOR')
# ('DATOS COMPRADOR', 'NOMBRE COMPRADOR')
# ('NATURALEZA', 'Unnamed: 14_level_1')
# ('CAUDAL ', 'Unnamed: 15_level_1')
# ('UNIDAD\n CAUDAL', 'Unnamed: 16_level_1')
# ('TIPO \nDERECHO', 'Unnamed: 17_level_1')
# ('EJERCICIO', 'Unnamed: 18_level_1')
# ('FUENTE', 'Unnamed: 19_level_1')
# ('VALOR \nTRANSACCION TOTAL', 'Unnamed: 20_level_1')
# ('UNIDAD', 'Unnamed: 21_level_1')
# ('OBSERVACIÓN', 'Unnamed: 22_level_1')
# 0      2012
# 1      2012
# 2      2010
# 3      2010
# 4      2010
#        ...
# 257    2012
# 258    2011
# 259    2011
# 260    2011
# 261    2011
# Name: REGISTRO ACTUAL REGISTRO AÑO, Length: 262, dtype: int64
# REGISTRO_CBR_DE_DERECHOS_NC_RECIBIDOS_EN_EL_MES_DE_MAYO_2012.xls
# 61
# ('REGIÓN', 'Unnamed: 0_level_1')
# ('LUGAR CBR', 'Unnamed: 1_level_1')
# ('Registro Actual', 'REGISTRO\nAÑO')
# ('Registro Actual', 'NUMERO')
# ('Registro Actual', 'FOJAS')
# ('TIPO TRANSACCION', 'Unnamed: 5_level_1')
# ('FECHA DE INSCRIPCION EN EL CBR', 'Unnamed: 6_level_1')
# ('DATOS VENDEDOR', 'RUT\nVENDEDOR')
# ('DATOS VENDEDOR', 'NOMBRE VENDEDOR')
# ('Registro Anterior', 'REGISTRO\nAÑO')
# ('Registro Anterior', 'NUMERO')
# ('Registro Anterior', 'FOJAS')
# ('DATOS COMPRADOR', 'RUT\nCOMPRADOR')
# ('DATOS COMPRADOR', 'NOMBRE COMPRADOR')
# ('NATURALEZA', 'Unnamed: 14_level_1')
# ('CAUDAL ', 'Unnamed: 15_level_1')
# ('UNIDAD\n CAUDAL', 'Unnamed: 16_level_1')
# ('TIPO \nDERECHO', 'Unnamed: 17_level_1')
# ('EJERCICIO', 'Unnamed: 18_level_1')
# ('FUENTE', 'Unnamed: 19_level_1')
# ('VALOR \nTRANSACCION', 'Unnamed: 20_level_1')
# ('UNIDAD', 'Unnamed: 21_level_1')
# ('OBSERVACIÓN', 'Unnamed: 22_level_1')
# 0     2012
# 1     2012
# 2     2012
# 3     2012
# 4     2012
# 5     2012
# 6     2012
# 7     2012
# 8     2012
# 9     2012
# 10    2012
# 11    2012
# 12    2012
# 13    2012
# 14    2012
# 15    2012
# 16    2012
# 17    2012
# 18    2012
# 19    2012
# 20    2012
# 21    2012
# 22    2012
# 23    2012
# 24    2012
# 25    2012
# 26    2012
# 27    2012
# 28    2012
# 29    2012
# 30    2012
# 31    2012
# 32    2012
# 33    2012
# 34    2012
# 35    2012
# 36    2012
# 37    2012
# 38    2012
# 39    2012
# 40    2012
# 41    2012
# 42    2012
# 43    2012
# 44    2012
# 45    2012
# 46    2012
# 47    2012
# 48    2012
# 49    2012
# 50    2012
# 51    2012
# 52    2012
# 53    2012
# 54    2012
# 55    2012
# 56    2012
# 57    2012
# 58    2012
# Name: REGISTRO ACTUAL REGISTRO AÑO, dtype: int64
# REGISTRO_CBR_DE_DERECHOS_NC_RECIBIDOS_MES_DE_ABRIL_2012.xls
# 72
# ('REGIÓN', 'Unnamed: 0_level_1')
# ('LUGAR CBR', 'Unnamed: 1_level_1')
# ('Registro Actual', 'REGISTRO\nAÑO')
# ('Registro Actual', 'NUMERO')
# ('Registro Actual', 'FOJAS')
# ('TIPO TRANSACCION', 'Unnamed: 5_level_1')
# ('FECHA DE INSCRIPCION EN EL CBR', 'Unnamed: 6_level_1')
# ('DATOS VENDEDOR', 'RUT\nVENDEDOR')
# ('DATOS VENDEDOR', 'NOMBRE VENDEDOR')
# ('Registro Anterior', 'REGISTRO\nAÑO')
# ('Registro Anterior', 'NUMERO')
# ('Registro Anterior', 'FOJAS')
# ('DATOS COMPRADOR', 'RUT\nCOMPRADOR')
# ('DATOS COMPRADOR', 'NOMBRE COMPRADOR')
# ('NATURALEZA', 'Unnamed: 14_level_1')
# ('CAUDAL ', 'Unnamed: 15_level_1')
# ('UNIDAD\n CAUDAL', 'Unnamed: 16_level_1')
# ('TIPO \nDERECHO', 'Unnamed: 17_level_1')
# ('EJERCICIO', 'Unnamed: 18_level_1')
# ('FUENTE', 'Unnamed: 19_level_1')
# ('VALOR \nTRANSACCION', 'Unnamed: 20_level_1')
# ('UNIDAD', 'Unnamed: 21_level_1')
# ('OBSERVACIÓN', 'Unnamed: 22_level_1')
# 0     2012
# 1     2012
# 2     2012
# 3     2012
# 4     2012
#       ...
# 65    2007
# 66    2007
# 67    2007
# 68    2007
# 69    2007
# Name: REGISTRO ACTUAL REGISTRO AÑO, Length: 70, dtype: int64
# REGISTRO_CBR_DE_DERECHOS_NC_RECIBIDOS_MES_DE_JUNIO_2012.xls
# 264
# ('REGIÓN', 'Unnamed: 0_level_1')
# ('LUGAR CBR', 'Unnamed: 1_level_1')
# ('Registro Actual', 'REGISTRO\nAÑO')
# ('Registro Actual', 'NUMERO')
# ('Registro Actual', 'FOJAS')
# ('TIPO TRANSACCION', 'Unnamed: 5_level_1')
# ('FECHA DE INSCRIPCION EN EL CBR', 'Unnamed: 6_level_1')
# ('DATOS VENDEDOR', 'RUT\nVENDEDOR')
# ('DATOS VENDEDOR', 'NOMBRE VENDEDOR')
# ('Registro Anterior', 'REGISTRO\nAÑO')
# ('Registro Anterior', 'NUMERO')
# ('Registro Anterior', 'FOJAS')
# ('DATOS COMPRADOR', 'RUT\nCOMPRADOR')
# ('DATOS COMPRADOR', 'NOMBRE COMPRADOR')
# ('NATURALEZA', 'Unnamed: 14_level_1')
# ('CAUDAL ', 'Unnamed: 15_level_1')
# ('UNIDAD\n CAUDAL', 'Unnamed: 16_level_1')
# ('TIPO \nDERECHO', 'Unnamed: 17_level_1')
# ('EJERCICIO', 'Unnamed: 18_level_1')
# ('FUENTE', 'Unnamed: 19_level_1')
# ('VALOR \nTRANSACCION TOTAL', 'Unnamed: 20_level_1')
# ('UNIDAD', 'Unnamed: 21_level_1')
# ('OBSERVACIÓN', 'Unnamed: 22_level_1')
# 0      2012
# 1      2012
# 2      2010
# 3      2010
# 4      2010
#        ...
# 257    2012
# 258    2012
# 259    2012
# 260    2011
# 261    2011
# Name: REGISTRO ACTUAL REGISTRO AÑO, Length: 262, dtype: int64
# REGISTRO_CBR_DE_DERECHOS_NC_RECIBIDOS_MES_DICIEMBRE_2011.xls
# 409
# ('REGIÓN', 'Unnamed: 0_level_1')
# ('LUGAR CBR', 'Unnamed: 1_level_1')
# ('Registro Actual', 'REGISTRO\nAÑO')
# ('Registro Actual', 'NUMERO')
# ('Registro Actual', 'FOJAS')
# ('TIPO TRANSACCION DEFINIDA POR CBR', 'Unnamed: 5_level_1')
# ('FECHA DE INSCRIPCION EN EL CBR', 'Unnamed: 6_level_1')
# ('DATOS VENDEDOR', 'RUT\nVENDEDOR')
# ('DATOS VENDEDOR', 'NOMBRE VENDEDOR')
# ('Registro Anterior', 'REGISTRO\nAÑO')
# ('Registro Anterior', 'NUMERO')
# ('Registro Anterior', 'FOJAS')
# ('DATOS COMPRADOR', 'RUT\nCOMPRADOR')
# ('DATOS COMPRADOR', 'NOMBRE COMPRADOR')
# ('NATURALEZA', 'Unnamed: 14_level_1')
# ('CAUDAL ', 'Unnamed: 15_level_1')
# ('UNIDAD\n CAUDAL', 'Unnamed: 16_level_1')
# ('TIPO \nDERECHO', 'Unnamed: 17_level_1')
# ('EJERCICIO', 'Unnamed: 18_level_1')
# ('FUENTE', 'Unnamed: 19_level_1')
# ('VALOR \nTRANSACCION', 'Unnamed: 20_level_1')
# ('UNIDAD', 'Unnamed: 21_level_1')
# ('OBSERVACIÓN1', 'Unnamed: 22_level_1')
# 0      2011
# 1      2011
# 2      2011
# 3      2011
# 4      2011
#        ...
# 402    2008
# 403    2009
# 404    2009
# 405    2009
# 406    2009
# Name: REGISTRO ACTUAL REGISTRO AÑO, Length: 407, dtype: int64
# REGISTRO_CBR_DE_DERECHOS_NC_RECIBIDOS_MES_ENERO_2012.xls
# 788
# ('REGIÓN', 'Unnamed: 0_level_1')
# ('LUGAR CBR', 'Unnamed: 1_level_1')
# ('Registro Actual', 'REGISTRO\nAÑO')
# ('Registro Actual', 'NUMERO')
# ('Registro Actual', 'FOJAS')
# ('TIPO TRANSACCION', 'Unnamed: 5_level_1')
# ('FECHA DE INSCRIPCION EN EL CBR', 'Unnamed: 6_level_1')
# ('DATOS VENDEDOR', 'RUT\nVENDEDOR')
# ('DATOS VENDEDOR', 'NOMBRE VENDEDOR')
# ('Registro Anterior', 'REGISTRO\nAÑO')
# ('Registro Anterior', 'NUMERO')
# ('Registro Anterior', 'FOJAS')
# ('DATOS COMPRADOR', 'RUT\nCOMPRADOR')
# ('DATOS COMPRADOR', 'NOMBRE COMPRADOR')
# ('NATURALEZA', 'Unnamed: 14_level_1')
# ('CAUDAL ', 'Unnamed: 15_level_1')
# ('UNIDAD\n CAUDAL', 'Unnamed: 16_level_1')
# ('TIPO \nDERECHO', 'Unnamed: 17_level_1')
# ('EJERCICIO', 'Unnamed: 18_level_1')
# ('FUENTE', 'Unnamed: 19_level_1')
# ('VALOR \nTRANSACCION', 'Unnamed: 20_level_1')
# ('UNIDAD', 'Unnamed: 21_level_1')
# ('OBSERVACIÓN', 'Unnamed: 22_level_1')
# 0      2011
# 1      2011
# 2      2011
# 3      2011
# 4      2011
#        ...
# 781    2011
# 782    2011
# 783    2011
# 784    2011
# 785    2011
# Name: REGISTRO ACTUAL REGISTRO AÑO, Length: 786, dtype: int64
# REGISTRO_CBR_JULIO_2015.xls
# 89
# ('NUMERO', 'Unnamed: 0_level_1')
# ('REGIÓN', 'Unnamed: 1_level_1')
# ('LUGAR CBR', 'Unnamed: 2_level_1')
# ('REGISTRO ACTUAL', 'REGISTRO\nAÑO')
# ('REGISTRO ACTUAL', 'NUMERO')
# ('REGISTRO ACTUAL', 'FOJAS')
# ('TIPO TRANSACCION', 'Unnamed: 6_level_1')
# ('FECHA DE INSCRIPCION EN EL CBR', 'Unnamed: 7_level_1')
# ('DATOS VENDEDOR', 'RUT VENDEDOR')
# ('DATOS VENDEDOR', 'NOMBRE VENDEDOR')
# ('REGISTRO ANTERIOR', 'REGISTRO\nAÑO')
# ('REGISTRO ANTERIOR', 'NUMERO')
# ('REGISTRO ANTERIOR', 'FOJAS')
# ('DATOS COMPRADOR', 'RUT\nCOMPRADOR')
# ('DATOS COMPRADOR', 'NOMBRE COMPRADOR')
# ('NATURALEZA', 'Unnamed: 15_level_1')
# ('CAUDAL ', 'Unnamed: 16_level_1')
# ('UNIDAD\n CAUDAL', 'Unnamed: 17_level_1')
# ('TIPO \nDERECHO', 'Unnamed: 18_level_1')
# ('EJERCICIO', 'Unnamed: 19_level_1')
# ('FUENTE', 'Unnamed: 20_level_1')
# ('VALOR \nTRANSACCION', 'Unnamed: 21_level_1')
# ('UNIDAD', 'Unnamed: 22_level_1')
# ('OBSERVACIÓN', 'Unnamed: 23_level_1')
# ('OBSERVACIÓN', 'Unnamed: 24_level_1')
# 0     2015.0
# 1     2015.0
# 2     2015.0
# 3     2015.0
# 4     2015.0
# 5     2015.0
# 6     2015.0
# 7     2015.0
# 8     2015.0
# 9     2015.0
# 10    2015.0
# 11    2015.0
# 12    2015.0
# 13    2015.0
# 14    2015.0
# 15    2015.0
# 16    2015.0
# 17    2015.0
# 18    2015.0
# 86       NaN
# Name: REGISTRO ACTUAL REGISTRO AÑO, dtype: float64
# REGISTRO_CBR_NC_CONCEDIDOS_EN_EL_MES_DE_ENERO_DE_2019.xls
# 32
# ('NUMERO', 'Unnamed: 0_level_1')
# ('REGIÓN', 'Unnamed: 1_level_1')
# ('LUGAR CBR', 'Unnamed: 2_level_1')
# ('REGISTRO ACTUAL', 'REGISTRO\nAÑO')
# ('REGISTRO ACTUAL', 'NUMERO')
# ('REGISTRO ACTUAL', 'FOJAS')
# ('TIPO TRANSACCION', 'Unnamed: 6_level_1')
# ('FECHA DE INSCRIPCION EN EL CBR', 'Unnamed: 7_level_1')
# ('DATOS VENDEDOR', 'RUT VENDEDOR')
# ('DATOS VENDEDOR', 'NOMBRE VENDEDOR')
# ('REGISTRO ANTERIOR', 'REGISTRO\nAÑO')
# ('REGISTRO ANTERIOR', 'NUMERO')
# ('REGISTRO ANTERIOR', 'FOJAS')
# ('DATOS COMPRADOR', 'RUT\nCOMPRADOR')
# ('DATOS COMPRADOR', 'NOMBRE COMPRADOR')
# ('NATURALEZA', 'Unnamed: 15_level_1')
# ('CAUDAL ', 'Unnamed: 16_level_1')
# ('UNIDAD\n CAUDAL', 'Unnamed: 17_level_1')
# ('TIPO \nDERECHO', 'Unnamed: 18_level_1')
# ('EJERCICIO', 'Unnamed: 19_level_1')
# ('FUENTE', 'Unnamed: 20_level_1')
# ('VALOR \nTRANSACCION', 'Unnamed: 21_level_1')
# ('UNIDAD', 'Unnamed: 22_level_1')
# ('OBSERVACIÓN', 'Unnamed: 23_level_1')
# 0     2019
# 1     2019
# 2     2019
# 3     2019
# 4     2019
# 5     2019
# 6     2019
# 7     2018
# 8     2018
# 9     2018
# 10    2018
# 11    2018
# 12    2018
# 13    2018
# 14    2018
# 15    2018
# 16    2018
# 17    2018
# 18    2018
# 19    2018
# 20    2018
# 21    2018
# 22    2018
# 23    2018
# 24    2018
# 25    2018
# 26    2018
# 27    2018
# 28    2018
# 29    2018
# Name: REGISTRO ACTUAL REGISTRO AÑO, dtype: int64
# REGISTRO_CBR__marzo2015.xls
# 47
# ('NUMERO', 'Unnamed: 0_level_1')
# ('REGIÓN', 'Unnamed: 1_level_1')
# ('LUGAR CBR', 'Unnamed: 2_level_1')
# ('REGISTRO ACTUAL', 'REGISTRO\nAÑO')
# ('REGISTRO ACTUAL', 'NUMERO')
# ('REGISTRO ACTUAL', 'FOJAS')
# ('TIPO TRANSACCION', 'Unnamed: 6_level_1')
# ('FECHA DE INSCRIPCION EN EL CBR', 'Unnamed: 7_level_1')
# ('DATOS VENDEDOR', 'RUT VENDEDOR')
# ('DATOS VENDEDOR', 'NOMBRE VENDEDOR')
# ('REGISTRO ANTERIOR', 'REGISTRO\nAÑO')
# ('REGISTRO ANTERIOR', 'NUMERO')
# ('REGISTRO ANTERIOR', 'FOJAS')
# ('DATOS COMPRADOR', 'RUT\nCOMPRADOR')
# ('DATOS COMPRADOR', 'NOMBRE COMPRADOR')
# ('NATURALEZA', 'Unnamed: 15_level_1')
# ('CAUDAL ', 'Unnamed: 16_level_1')
# ('UNIDAD\n CAUDAL', 'Unnamed: 17_level_1')
# ('TIPO \nDERECHO', 'Unnamed: 18_level_1')
# ('EJERCICIO', 'Unnamed: 19_level_1')
# ('FUENTE', 'Unnamed: 20_level_1')
# ('VALOR \nTRANSACCION', 'Unnamed: 21_level_1')
# ('UNIDAD', 'Unnamed: 22_level_1')
# ('OBSERVACIÓN', 'Unnamed: 23_level_1')
# ('OBSERVACIÓN', 'Unnamed: 24_level_1')
# 0     2014.0
# 1     2014.0
# 2     2015.0
# 3     2015.0
# 4     2014.0
# 5     2014.0
# 6     2014.0
# 7     2015.0
# 8     2015.0
# 9     2015.0
# 10    2015.0
# 11    2015.0
# 12    2015.0
# 13    2015.0
# 14    2015.0
# 15    2015.0
# 16    2015.0
# 17    2015.0
# 18    2015.0
# 19    2015.0
# 20    2015.0
# 21    2015.0
# 22    2015.0
# 23    2015.0
# 24    2015.0
# 25    2015.0
# 26    2015.0
# 27    2015.0
# 28    2015.0
# 29    2015.0
# 30    2014.0
# 31    2014.0
# 32    2014.0
# 33    2014.0
# 34    2014.0
# 35    2015.0
# 36    2015.0
# 37    2015.0
# 44       NaN
# Name: REGISTRO ACTUAL REGISTRO AÑO, dtype: float64
